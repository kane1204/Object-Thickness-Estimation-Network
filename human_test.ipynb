# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mplcursors
from PIL import Image
dir = "data\human_samples"

# %%
# Read in all the images and csv file and randomly label the images with a red or blue dot
import ast
 
imgs = []
points =  [[],[]]*10
# read in csv file
real_df = pd.read_csv("human_sample_actuals.csv", index_col=0)

# %%
label_thicker = {}
real_df['label'] = None
for num, data in real_df.iterrows():
    img_file = join(dir, data["file_name"], "img.png")
    # pick which point will be red and which will be blue
    if np.random.randint(2) == 0:
        redpt = data["thicker"]
        bluept = data["thinner"]
        label_thicker[num] = "red"
    else:
        redpt = data["thinner"]
        bluept = data["thicker"]
        label_thicker[num] = "blue"
    
    #  append the label to the dataframe
    real_df["label"].iloc[num] = label_thicker[num]

    # real_df['label'] = label_thicker[num]
    # read in the image and add the red and blue dots
    redpt = ast.literal_eval(redpt)
    bluept =  ast.literal_eval(bluept)

    image = Image.open(img_file)
    # add red dot
    image.putpixel((redpt[1],redpt[0]), (255,0,0))
    image.putpixel((redpt[1]+1,redpt[0]), (255,0,0))
    image.putpixel((redpt[1]-1,redpt[0]), (255,0,0))
    image.putpixel((redpt[1],redpt[0]+1), (255,0,0))
    image.putpixel((redpt[1],redpt[0]-1), (255,0,0))
    # add a larger blue dot
    image.putpixel((bluept[1],bluept[0]), (0,0,255))
    image.putpixel((bluept[1]+1,bluept[0]), (0,0,255))
    image.putpixel((bluept[1]-1,bluept[0]), (0,0,255))
    image.putpixel((bluept[1],bluept[0]+1), (0,0,255))
    image.putpixel((bluept[1],bluept[0]-1), (0,0,255))
    # save the image
    image.save(join(dir,"labeled_samples", str(num)+"_labeled.png"))
print(label_thicker)
real_df.to_csv("human_sample_actuals.csv")
# Out:
# {0: 'red', 1: 'blue', 2: 'blue', 3: 'blue', 4: 'red', 5: 'blue', 6: 'blue', 7: 'blue', 8: 'red', 9: 'red'}

# %%
real_df
# Out:
#                                            file_name   thicker   thinner label
# 0  02808440\88d183f319cddb7344221bef0fa3c36b\frame_0  (48, 50)  (65, 88)   red
# 1  02880940\899af991203577f019790c8746d79a6f\frame_0  (67, 58)  (76, 76)  blue
# 2  02942699\ce40b134b11e8c822bbc2c380e91dfe2\frame_1  (92, 61)  (76, 64)  blue
# 3  02958343\ba494b33be3a3e0dc1bbb501b1d87871\frame_1  (52, 67)  (77, 71)  blue
# 4  03761084\46dbba829a57ace8cffd61677456447e\frame_0  (52, 65)  (54, 76)   red
# 5  03991062\67bc9bec05f78850f9e08161aea27d2f\frame_0  (65, 62)  (57, 75)  blue
# 6  04225987\1d527bbed4d12817fa3bb91f4e3cd35f\frame_0  (68, 47)  (64, 58)  blue
# 7  04256520\bc6a3fa659dd7ec0c62ac18334863d36\frame_1  (78, 42)  (48, 51)  blue
# 8  04401088\f400eb5421283e8a102f4912aece242b\frame_2  (73, 64)  (43, 60)   red
# 9  04460130\15cc3d9020384e8d6e09a8e31c7575c5\frame_2  (64, 66)  (31, 84)   red
